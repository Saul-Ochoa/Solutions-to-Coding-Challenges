# %% [markdown]
# # General Instructions
# You are only allowed to use numpy and pandas libraries from python (except if it says otherwise) for all this test.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Variable Simulation with numpy
# For this section you are only allowed to use numpy library.

# %% [markdown]
# **1.1** Define a python’s function that simulates a vector of shape=(100,1) (i.e. 100 rows and 1 column) where each element $\epsilon_t$ is equal to the realization of a normal random variable with mean 0 and standard deviation 1.  ( $\epsilon_t$ ~ $N(0,1)$)

# %% [markdown]
# **1.2.** Simulate 2 vectors $X^{(1)}$ and $X^{(2)}$ of shape=(100,1) each, where each element is equal to:
#
# $x^{(1)}_t = 0.5 x^{(1)}_{t-1}+\epsilon^{(1)}_t$   Where $\epsilon^{(1)}_t$ ~ $N(0,1)$ and $x^{(1)}_0=0$
#
# $x^{(2)}_t = 0.8 x^{(2)}_{t-1}+\epsilon^{(2)}_t$ Where $\epsilon^{(2)}_t$ ~ $N(0,1)$ and $x^{(2)}_0=0$
#
# Of course, the vectors $X^{(1)}$ and $X^{(2)}$ are:
#
# $X^{(1)}=[x^{(1)}_0, x^{(1)}_1,x^{(1)}_2,...,x^{(1)}_{99}]'$
#
# $X^{(2)}=[x^{(2)}_0, x^{(2)}_1,x^{(2)}_2,...,x^{(2)}_{99}]'$

# %% [markdown]
# ## 2. Dataframe manipulation with Pandas
# For this section, you are only allowed to use pandas or maybe numpy.

# %% [markdown]
# Some text files with data from identify people by RENIEC from 2014 through 2020 (pob_identifi
# cada_YYYY.txt) will be share to you. Before you begin to answer any question in this section, you
# have to load these files and consolidate them into a single DataFrame (df).

# %% [markdown]
# **2.1.** How many nonresident male were identified from 2018 through 2019?

# %% [markdown]
# **2.2.** From 2016 through 2018 and in the department of Arequipa. What percentage of women represent female teenagers? [Hint: a teenager is a person whose age is between 10 to 19 years]

# %% [markdown]
# **2.3.** From 2014 through 2020, which year the average age of elderly people (age equal or greather than 60 years) identified was the higher?

# %% [markdown]
# ## 3. Object Oriented Programming with Python
# Write a Python program to create a ProfitabilityIndicators class with (you are **not allowed** to use numpy financial):

# %% [markdown]
# I. investment, cash_flow, equity and period instance attributes
#
# II. Four customs methods that calculates:<br>
#   &emsp;a. Internal Rate of Return (IRR) called get_irr()<br>
#   &emsp;b. Net Present Value (NPV) called get_npv()<br>
#   &emsp;c. Return on Asset (ROA) called get_roa()<br>
#   &emsp;d. Return on Equity (ROE) called get_roe()<br>
#
# III. Example usage:<br>
# &emsp;investment = -150000<br>
# &emsp;cash_flow = [25000, 35000, 40000, 50000, 55000]<br>
# &emsp;balance = [150000, 130000, 105000, 75000, 40000, 0]<br>
# &emsp;equity = [50000, 60000, 70000, 80000, 90000]<br>
# &emsp;period = 5<br>
# &emsp;rate = 0.05<br>

# %% [markdown]
# ## 4. Machine Learning Algorithms
# **For this section, you are only allowed to use pandas, numpy, scikit-learn and if necessary matplotlib**
#
# The iris dataset will be used for this exercise, please load from scikit-learn and consolidate as a DataFrame, generate a *species* column with names of categories (setosa, versicolor, virginica).
#
# Please use a logistic regression model. Also, this is a model in train and test sample, so please use
# this random seed: 42

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# **4.1** Using either feature reduction or feature selection, choose only 2 variables to generate a multiclass classification model (species column as target).<br>
# Please write variable’s name correctly

# %% [markdown]
# **4.2** Show confusion matrix through a heatmap

# %% [markdown]
# **4.2.1.** Confusion matrix

# %% [markdown]
# **4.2.2.** Heatmap

# %% [markdown]
# **4.3** Calculate this metrics, also give some explanations about it:<br>
# I. Gini coefficient either train and test sample.<br>
# II. Recall index<br>
# III. Precision

# %% [markdown]
# **4.2.2.** Gini coefficient

# %% [markdown]
# **4.2.2.** Recall index

# %% [markdown]
# **4.2.2.** Precision

# %% [markdown]
# ## 5. Missing-data Inputation
# **For this section, you are only allowed to use pandas, numpy, matplotlib/seaborn and scikit-learn**
#
# The data_inputation dataset contains basic information of 500 people's physical characteristics. However, there are some missing values on the weight column, wich has been found to be a good predictor for an specific model.
#
# Read the dataset as a panda's DataFrame. For this task, you can create new columns but do not change the name of the original ones.

# %% [markdown]
# **5.1.** Fill the missing values in the Weight column, explain your thought process
